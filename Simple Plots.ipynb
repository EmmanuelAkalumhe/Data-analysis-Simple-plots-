# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\eakal\Desktop\DSL\DSL Projects\Book.csv")

# %%
df
# Out:
#            Complaint_Type  No_of_Complaints
# 0            Delay in Reg                43
# 1           Room Cleaning                34
# 2            Food Quality                17
# 3   Delay in Room Service                 9
# 4          Staff Attitude                 6
# 5          Room interiors                 6
# 6        Air conditioning                 3
# 7               Concierge                 2
# 8                Mini Bar                 2
# 9             Parking Lot                 5
# 10         Swimming Pool                 14

# %%
df.head()
# Out:
#           Complaint_Type  No_of_Complaints
# 0           Delay in Reg                43
# 1          Room Cleaning                34
# 2           Food Quality                17
# 3  Delay in Room Service                 9
# 4         Staff Attitude                 6

# %%
# Line Plot
plt.plot(df['No_of_Complaints'], df['Complaint_Type']);
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Bar Graph
plt.bar(df['No_of_Complaints'], df['Complaint_Type']);

# %%
# Horizontal Bar Graph
plt.barh(df['Complaint_Type'], df['No_of_Complaints']);

# %%
# Scatter Plot
plt.scatter(df['No_of_Complaints'], df['Complaint_Type']);

# %%
# Bubble Plot
plt.scatter(df['No_of_Complaints'], df['Complaint_Type'])
